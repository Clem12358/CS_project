# %%
# !pip install cloudscraper beautifulsoup4

# %%
import sys
print(sys.executable)  # should end with .../tm_scrape/.venv/bin/python
# Out:
# /Users/clementdurix/tm_scrape/.venv/bin/python

# %% [markdown]
# ## You need to Select the kernel "Python (tm-scrape venv) (Python 3.12.0)" for it to work

# %%
import csv, time, random
from bs4 import BeautifulSoup
import cloudscraper
from pathlib import Path  # can be at top of the notebook too

urls = [
    "https://www.transfermarkt.com/fc-zurich/spielplandatum/verein/260/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1", # FC zurich 19-20
    "https://www.transfermarkt.com/fc-zurich/spielplandatum/verein/260/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1", # 20-21
    "https://www.transfermarkt.com/fc-zurich/spielplandatum/verein/260/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1", # 21-22
    "https://www.transfermarkt.com/fc-zurich/spielplandatum/verein/260/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1", # 22-23
    "https://www.transfermarkt.com/fc-zurich/spielplandatum/verein/260/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1", # 23-24
    "https://www.transfermarkt.com/fc-zurich/spielplandatum/verein/260/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1", # 24-25
    "https://www.transfermarkt.com/fc-zurich/spielplandatum/verein/260/saison_id/2025/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1", # 25-26
    "https://www.transfermarkt.com/fc-lausanne-sport/spielplandatum/verein/527/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # lausanne 19-20
    "https://www.transfermarkt.com/fc-lausanne-sport/spielplandatum/verein/527/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 20-21
    "https://www.transfermarkt.com/fc-lausanne-sport/spielplandatum/verein/527/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 21-22
    "https://www.transfermarkt.com/fc-lausanne-sport/spielplandatum/verein/527/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 22-23
    "https://www.transfermarkt.com/fc-lausanne-sport/spielplandatum/verein/527/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 23-24
    "https://www.transfermarkt.com/fc-lausanne-sport/spielplandatum/verein/527/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 24-25
    "https://www.transfermarkt.com/fc-lausanne-sport/spielplandatum/verein/527/saison_id/2025/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",    # 25-26
    "https://www.transfermarkt.com/servette-fc/spielplandatum/verein/61/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # Geneve Servette 19-20
    "https://www.transfermarkt.com/servette-fc/spielplandatum/verein/61/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 20-21
    "https://www.transfermarkt.com/servette-fc/spielplandatum/verein/61/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 21-22
    "https://www.transfermarkt.com/servette-fc/spielplandatum/verein/61/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 22-23
    "https://www.transfermarkt.com/servette-fc/spielplandatum/verein/61/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 23-24
    "https://www.transfermarkt.com/servette-fc/spielplandatum/verein/61/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 24-25
    "https://www.transfermarkt.com/servette-fc/spielplandatum/verein/61/saison_id/2025/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",    # 25-26
    "https://www.transfermarkt.com/bsc-young-boys/spielplandatum/verein/452/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # BSC Young Boys 19-20
    "https://www.transfermarkt.com/bsc-young-boys/spielplandatum/verein/452/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 20-21
    "https://www.transfermarkt.com/bsc-young-boys/spielplandatum/verein/452/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 21-22
    "https://www.transfermarkt.com/bsc-young-boys/spielplandatum/verein/452/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  #
wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 24-25
    "https://www.transfermarkt.com/grasshopper-club-zurich/spielplandatum/verein/504/saison_id/2025/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",    # 25-26
]


# Realistic headers to make my script look like a normal browser and control what language of the page you land on.
headers = {
    # first we set "who" is making the request:
    "User-Agent": ("Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                   "AppleWebKit/537.36 (KHTML, like Gecko) "
                   "Chrome/124.0 Safari/537.36"),
    # not to get German/French/Italian...:
    "Accept-Language": "en-US,en;q=0.9",
    # tell the site from which page we come from:
    "Referer": "https://www.transfermarkt.com/"
}

def try_fetch(scraper, url): # a little helper, def try_fetch(scraper, url):
    """Warm up cookies on .com, then try .com, .co.uk, .de"""
    # warm-up hit, it goes to Transfermarkt homepage, helps the session collect any cookies that the site uses, and it keeps it and automatically reuses it on the next request.
    scraper.get("https://www.transfermarkt.com/", headers=headers, timeout=30)
    for tld in ("com", "co.uk", "de"):
        test = url.replace("transfermarkt.com", f"transfermarkt.{tld}") # Sometimes one domain blocks while another works fine, so we try on three of them one by one and stop when we find one that actually works
        r = scraper.get(test, headers=headers, timeout=30) 
        if r.status_code == 200 and "<table" in r.text: # we can still get a code =200 even if we land on an unusable page, to confirm the page is one we can scrape from, we check in the HTML that there is a <table
            return r.text
        time.sleep(1 + random.random()) # I stay polite to the website + make sure it doesn't look too "robotic"
    return None
    

# we set the columns names
cols = [
    "Competition","Matchday","Date","Time",
    "Home Team","Ranking Home Team","Away Team","Ranking Away Team",
    "Attendance","Result"
]
# create a tuple for rows
rows = []

scraper = cloudscraper.create_scraper(browser="chrome") # we create an HTTP session that behaves like chrome. also we keep cookies between requests.

for url in urls: # for loop with urls
    print("Scraping:", url) # we indicate that we are scraping it (debug code always useful)
    html = try_fetch(scraper, url) # we use the def we created above
    if not html:
        print("  ! Unable to fetch page, skipping.")
        continue

    soup = BeautifulSoup(html, "html.parser") # trasnform the HTML text into searchable objects
    wrapper = soup.find("div", class_="responsive-table") # in this HTML tranformed text we look for "div", class_="responsive-table" which is where the table lies
    if not wrapper:
        print("  ! No fixture table found, skipping.")
        continue

    table = wrapper.find("table") # now we go fetch in the HTML the table where the raw data lies
    current_competition = ""
    for tr in table.find("tbody").find_all("tr"): # we look at each row tr that that contain either a competition or a match
        # if a row is like this, it means it's a title, basically the name of the competition (a "comp_cell") for the following rows until another td hits (see the url to understand):
        comp_cell = tr.find("td", class_="extrarow") 
        if comp_cell:
            current_competition = comp_cell.get_text(strip=True)
            continue

        tds = tr.find_all("td")
        if len(tds) < 11: # a real match row has at least 11 cells, so if it has less it's not valid
            continue  # not a data row so we skip it and continue to next row

        # go fetch the valid rawdata
        matchday  = tds[0].get_text(strip=True)
        date      = tds[1].get_text(strip=True)
        time_     = tds[2].get_text(strip=True)

        home_cell = tds[4]
        away_cell = tds[6]
        home      = (home_cell.find("a") or home_cell).get_text(strip=True) # Normally the team name is inside an <a> but if it isn’t, we fall back on the whole cell’s text.
        away      = (away_cell.find("a") or away_cell).get_text(strip=True)
        hr = home_cell.find("span", class_="tabellenplatz")
        ar = away_cell.find("span", class_="tabellenplatz")
        home_rank = hr.get_text(strip=True) if hr else ""
        away_rank = ar.get_text(strip=True) if ar else ""

        attendance = tds[9].get_text(strip=True)
        result     = tds[10].get_text(strip=True)

        rows.append([current_competition, matchday, date, time_,
                     home, home_rank, away, away_rank, attendance, result]) # Put everything in a list in a fixed order:

    # insert a pause between page request to be polite to their servers (reduce their loads) & avoid hitting too many pages too quickly and too regularly to avoid being blocked
    time.sleep(2 + random.random())

# Write it as a csv & save it in folder
output_path = Path("/Users/clementdurix/Library/CloudStorage/OneDrive-Personal/1. UNI/ComputerScience/CS_project/Data/RawData/RawData_Transfermarkt.csv")

# create and open the file for writing. We also use newline="" to prevent seeing blank lines in the csv. Could have been done without the if but would require one more line "f.close()"
with output_path.open("w", newline="", encoding="utf-8") as f:
    # takes the file that we named above "f" and puts commas between values (for a csv)
    writer = csv.writer(f)
    # write the header line
    writer.writerow(cols)
    # write every inner list as lines
    writer.writerows(rows)

print("Done")
print(f"Saved to: {output_path}")
# Out:
# Scraping: https://www.transfermarkt.com/fc-zurich/spielplandatum/verein/260/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/fc-zurich/spielplandatum/verein/260/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/fc-zurich/spielplandatum/verein/260/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/fc-zurich/spielplandatum/verein/260/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/fc-zurich/spielplandatum/verein/260/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/fc-zurich/spielplandatum/verein/260/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# ...

# %%
# %pip install -q pandas  # first time only
import pandas as pd

df = pd.DataFrame(rows, columns=cols)
display(df.sample(15, random_state=0))  # random 10

# quick sanity summaries
print("Rows:", len(df))
print("Competitions:", df["Competition"].nunique())
print(df["Competition"].value_counts().head())
# Out:
# Note: you may need to restart the kernel to use updated packages.
#      Competition Matchday          Date     Time        Home Team  \
# 4   Super League        6  Wed 14/08/19  7:00 PM        FC Zürich
# 28  Super League       26  Sun 28/06/20  4:00 PM        FC Zürich
# 29  Super League       27  Wed 01/07/20  8:30 PM          FC Thun
# 33  Super League       32  Sat 18/07/20  8:30 PM        FC Zürich
# 34  Super League       33  Wed 22/07/20  8:30 PM        FC Lugano
# 25  Super League       23  Sat 22/02/20  7:00 PM        FC Zürich
# 10  Super League        9  Sun 29/09/19  4:00 PM      Servette FC
# 22  Super League       20  Sun 02/02/20  4:00 PM          FC Sion
# 11  Super League       10  Sun 06/10/19  4:00 PM        FC Zürich
# 27  Super League       25  Thu 25/06/20  8:30 PM    FC St. Gallen
# 18  Super League       16  Sat 30/11/19  7:00 PM  Neuchâtel Xamax
# 15  Super League       13  Sat 02/11/19  7:00 PM          FC Thun
# ...
